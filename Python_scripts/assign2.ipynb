# %%
## Python scripts for US-Elections

# %%
# Import libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import seaborn as sns
sns.set_theme(color_codes=True)

# Load csv
education = pd.read_csv("../data/clean_data/analysis_data/voting_tendencies_by_education_level_2016.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-631011ed245f> in <module>
#       5 import numpy as np
#       6 import seaborn as sns
# ----> 7 sns.set_theme(color_codes=True)
#       8
#       9 # Load csv
#
# AttributeError: module 'seaborn' has no attribute 'set_theme'

# %%
education.head()
# Out:
#         state  bachelor_or_higher_perc  percentage_registered  democrats  \
# 0     Alabama                23.257142                  0.664    34.7778
# 1      Alaska                27.100000                  0.644    36.0000
# 2     Arizona                27.677778                  0.608    41.2333
# 3    Arkansas                21.375000                  0.558    35.1667
# 4  California                32.411321                  0.519    53.6250
#
#    republicans
# 0      54.7778
# 1      46.6667
# 2      42.9667
# 3      53.5833
# 4      31.4688

# %%
# x, y labels
education_bachelor_higher = education["bachelor_or_higher_perc"]
democrats = education["democrats"]
republicans = education["republicans"]

# plot voting tendencies with regression line
sns.regplot(x="bachelor_or_higher_perc", y="democrats", data=education, label = "democrats", scatter_kws={"color": "blue"}, line_kws={"color": "blue"})
sns.regplot(x="bachelor_or_higher_perc", y="republicans", data=education, label = "republicans", scatter_kws={"color": "red"}, line_kws={"color": "red"})

plt.title('Voting Tendency by Education Level')
plt.xlabel('% of Bachelor or Higher Education')
plt.ylabel('% of Votes')
plt.legend()
plt.savefig("../visualisations/voting_tendencies_education_level.jpg", dpi = 200)
plt.show()
