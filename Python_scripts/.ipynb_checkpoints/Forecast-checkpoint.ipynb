# %% [markdown]
# ## Loading libraries

# %%
#import the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os # to handle directory references

# %%
# Load the file for the Presidential state toplines
df = pd.read_csv("../data/clean_data/2020/presidential_state_toplines_2020.csv", encoding = 'utf-8')

# %%
# The first 5 rows of the file
df.head(5)
# Out:
#    cycle   modeldate candidate_inc candidate_chal          state   tipping  \
# 0   2020  10/05/2020         Trump          Biden        Wyoming  0.000000
# 1   2020  10/05/2020         Trump          Biden      Wisconsin  0.133563
# 2   2020  10/05/2020         Trump          Biden  West Virginia  0.000150
# 3   2020  10/05/2020         Trump          Biden     Washington  0.001250
# 4   2020  10/05/2020         Trump          Biden       Virginia  0.012525
#
#         vpi  winstate_inc  winstate_chal  voteshare_inc  ...  margin_hi  \
# 0  0.000000      0.998625       0.001375       68.59200  ...  51.989000
# 1  6.218521      0.177200       0.822800       46.53666  ...   2.330732
# 2  0.032301      0.993350       0.006650       65.88024  ...  47.157420
# 3  0.048835      0.007800       0.992200       36.58363  ... -13.420110
# 4  0.423182      0.026500       0.973500       43.55361  ...  -4.309885
#
#    margin_lo  win_EC_if_win_state_inc  win_EC_if_win_state_chal  \
# 0   28.18282                 0.181800                  0.963636
# 1  -14.24209                 0.796981                  0.948226
# 2   19.85341                 0.182665                  0.977444
# 3  -35.97208                 0.548077                  0.816846
# 4  -19.40033                 0.929245                  0.834283
#
#    win_state_if_win_EC_inc  win_state_if_win_EC_chal  state_turnout  \
# 0                 0.999725                  0.001628       248682.0
# 1                 0.777671                  0.958477      3047938.0
# 2                 0.999174                  0.007985       685877.9
# 3                 0.023541                  0.995669      3578657.0
# 4                 0.135600                  0.997758      4222231.0
#
#    state_turnout_hi  state_turnout_lo        timestamp
# 0          289896.5          209278.5  5/10/2020 14:34
# 1         3441382.0         2659453.0  5/10/2020 14:34
# 2          794993.5          581345.5  5/10/2020 14:34
# 3         4062822.0         3105877.0  5/10/2020 14:34
# 4         4773274.0         3684266.0  5/10/2020 14:34
#
# [5 rows x 29 columns]

# %%
# Select the columns for the state, the date and the voteshare between Trump, Biden and other.
df = df[['modeldate','state','voteshare_inc', 'voteshare_chal', 'voteshare_other']]
df
# Out:
#        modeldate          state  voteshare_inc  voteshare_chal  \
# 0     10/05/2020        Wyoming       68.59200        28.45008
# 1     10/05/2020      Wisconsin       46.53666        52.51788
# 2     10/05/2020  West Virginia       65.88024        32.33737
# 3     10/05/2020     Washington       36.58363        61.30294
# 4     10/05/2020       Virginia       43.55361        55.44437
# ...          ...            ...            ...             ...
# 7107   6/01/2020     California       34.97393        63.09200
# 7108   6/01/2020       Arkansas       60.87153        37.47324
# 7109   6/01/2020        Arizona       48.75072        49.84497
# 7110   6/01/2020         Alaska       54.42247        43.01599
# 7111   6/01/2020        Alabama       59.78811        39.40047
#
#       voteshare_other
# 0            2.957924
# 1            0.945465
# 2            1.782385
# 3            2.113433
# 4            1.002013
# ...               ...
# 7107         1.934068
# 7108         1.655232
# 7109         1.404308
# 7110         2.561537
# 7111         0.811418
#
# [7112 rows x 5 columns]

# %%
# Average of the data by date and state.
df_avg = df.groupby(['modeldate','state']).mean()
df_avg
# Out:
#                           voteshare_inc  voteshare_chal  voteshare_other
# modeldate  state
# 10/01/2020 Alabama             58.48220        40.72155         0.796247
#            Alaska              52.58267        45.17170         2.245623
#            Arizona             48.04539        50.64658         1.308028
#            Arkansas            56.32597        42.08474         1.589298
#            California          34.02298        64.05972         1.917305
# ...                                 ...             ...              ...
# 9/30/2020  Virginia            44.04475        54.93501         1.020240
#            Washington          37.17141        60.66965         2.158944
#            West Virginia       66.00268        32.20667         1.790648
#            Wisconsin           46.52716        52.51878         0.954052
#            Wyoming             68.34772        28.35223         3.300052
#
# [7112 rows x 3 columns]

# %%
# Then i finally decided to group the data by state and used the average percentage of vote share.
df1 = df.groupby(['state']).mean()
df1
# Out:
#                       voteshare_inc  voteshare_chal  voteshare_other
# state
# Alabama                   59.557721       39.648648         0.793631
# Alaska                    53.476999       44.186375         2.336626
# Arizona                   48.386509       50.264777         1.348714
# Arkansas                  56.784881       41.585218         1.629902
# California                34.492683       63.581291         1.926026
# Colorado                  44.238472       53.869081         1.892447
# Connecticut               39.949516       59.120377         0.930107
# Delaware                  37.987829       60.855039         1.157133
# District of Columbia       5.912331       90.560841         3.526828
# Florida                   48.067099       51.124780         0.808120
# Georgia                   50.718680       48.463555         0.817765
# Hawaii                    31.160671       67.097833         1.741495
# Idaho                     62.390575       34.530974         3.078450
# Illinois                  38.854138       59.611081         1.534780
# Indiana                   55.603010       42.969759         1.427232
# Iowa                      51.106482       47.526368         1.367149
# Kansas                    55.449926       42.707177         1.842897
# Kentucky                  59.620629       39.178464         1.200907
# Louisiana                 57.151086       42.013964         0.834950
# ME-1                      39.322094       59.439700         1.238206
# ME-2                      50.419377       48.105936         1.474686
# Maine                     44.584453       54.065224         1.350323
# Maryland                  35.500560       63.130805         1.368635
# Massachusetts             33.788448       64.610608         1.600943
# Michigan                  45.448592       53.411484         1.139923
# Minnesota                 45.891118       52.648899         1.459983
# Mississippi               55.475548       43.735700         0.788752
# Missouri                  54.188867       44.362413         1.448720
# Montana                   55.078950       42.692264         2.228786
# NE-1                      56.321600       41.861359         1.817042
# NE-2                      48.356221       50.294408         1.349371
# NE-3                      72.356327       25.303705         2.339968
# Nebraska                  58.691401       39.486311         1.822288
# Nevada                    45.807776       52.442653         1.749571
# New Hampshire             46.304166       52.634395         1.061439
# New Jersey                40.353984       58.779863         0.866153
# New Mexico                42.831399       55.327703         1.840897
# New York                  36.624572       62.282824         1.092604
# North Carolina            49.260716       49.955623         0.783661
# North Dakota              60.724763       36.590395         2.684842
# Ohio                      49.762245       49.201428         1.036327
# Oklahoma                  63.004811       35.796103         1.199087
# Oregon                    41.584948       56.009607         2.405445
# Pennsylvania              47.100208       52.154661         0.745131
# Rhode Island              37.466113       61.095988         1.437899
# South Carolina            53.969007       45.142908         0.888084
# South Dakota              59.479097       39.032260         1.488643
# Tennessee                 57.490605       41.405040         1.104354
# Texas                     51.626483       47.362166         1.011350
# Utah                      56.518110       40.176821         3.305070
# Vermont                   31.446384       65.820206         2.733409
# Virginia                  43.898919       55.066152         1.034929
# Washington                37.059203       60.700543         2.240254
# West Virginia             65.828741       32.333400         1.837859
# Wisconsin                 46.731906       52.253206         1.014888
# Wyoming                   68.339772       28.265108         3.395120

# %%
# Sort the data in descending order to find a forecast of the top 10 states who are in favor of Trump winning the election.
df2=df1.sort_values(by=['voteshare_inc'], ascending=False)
df2 = df2.head(10)

# %%
#Plot a bar graph for the top 10 states in favor of Trump.
df2.plot(kind = 'bar', title = 'Forecast-Top 10 states in favor of Trump (5th October 2020)')
